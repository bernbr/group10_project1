# %%
# Import Dependancies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# Read CSV.files
aob_2010 = pd.read_csv("data/aob_2010.csv", thousands=',')
aob_2015 = pd.read_csv("data/aob_2015.csv", thousands=',')
aob_2020 = pd.read_csv("data/aob_2020.csv", thousands=',')
nob_2010 = pd.read_csv("data/nob_2010.csv", thousands=',')
nob_2015 = pd.read_csv("data/nob_2015.csv", thousands=',')
nob_2020 = pd.read_csv("data/nob_2020.csv", thousands=',')

# %%
# Drop unnamed columns in nob_2010
nob_2010 = nob_2010.drop(columns=['Unnamed: 14', 'Unnamed: 15'])

# %%
# List column names
nob_2015.columns
# Out:
# Index(['State or area', 'County', 'ANSI Code', 'Total',
#        'Retirement Retired workers', 'Retirement Spouses',
#        'Retirement Children', 'Survivors Widow(er)s and parents',
#        'Survivors Children', 'Disability Disabled workers',
#        'Disability Spouses', 'Disability Children', 'Aged 65 or older Men',
#        'Aged 65 or older Women'],
#       dtype='object')

# %%
# Convert data types for aob 2010
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
aob_2010 = aob_2010.astype(convert_dict)

# %%
# Convert data types for nob 2010
convert_dict = {"Total_people": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
nob_2010 = nob_2010.astype(convert_dict)

# %%
# Convert data types for aob 2015
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
aob_2015 = aob_2015.astype(convert_dict)

# %%
# Convert data types for nob 2015
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
nob_2015 = nob_2015.astype(convert_dict)

# %%
# Convert data types for aob 2020
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
aob_2020 = aob_2020.astype(convert_dict)

# %%
# Convert data types for nob 2020
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}
nob_2020 = nob_2020.astype(convert_dict)

# %%
# Merged Files
df_2010 = pd.merge(aob_2010, nob_2010, on=["State or area", "County"], how='outer')
df_2015 = pd.merge(aob_2015, nob_2015, on=["State or area", "County"], how='outer')
df_2020 = pd.merge(aob_2020, nob_2020, on=["State or area", "County"], how='outer')

# %%
# List column names
df_2010.columns
# Out:
# Index(['State or area', 'County', 'ANSI Code_x', 'Total',
#        'Retirement Retired workers_x', 'Retirement Spouses_x',
#        'Retirement Children_x', 'Survivors Widow(er)s and parents_x',
#        'Survivors Children_x', 'Disability Disabled workers_x',
#        'Disability Spouses_x', 'Disability Children_x',
#        'Aged 65 or older Men_x', 'Aged 65 or older Women_x', 'ANSI Code_y',
#        'Total_people', 'Retirement Retired workers_y', 'Retirement Spouses_y',
#        'Retirement Children_y', 'Survivors Widow(er)s and parents_y',
#        'Survivors Children_y', 'Disability Disabled workers_y',
#        'Disability Spouses_y', 'Disability Children_y',
#        'Aged 65 or older Men_y', 'Aged 65 or older Women_y'],
#       dtype='object')

# %%
# Display column heads
df_2010.head()
# Out:
#    State or area   County  ANSI Code_x       Total  \
# 0  United States      NaN          NaN  58048295.0
# 1        Alabama  Autauga       1001.0     10224.0
# 2        Alabama  Baldwin       1003.0     46097.0
# 3        Alabama  Barbour       1005.0      6213.0
# 4        Alabama     Bibb       1007.0      4960.0
#
#    Retirement Retired workers_x  Retirement Spouses_x  Retirement Children_x  \
# 0                    40662492.0             1343640.0               334405.0
# 1                        6352.0                 226.0                   57.0
# 2                       32376.0                1097.0                  251.0
# 3                        3636.0                 107.0                   31.0
# 4                        2608.0                  97.0                   31.0
#
#    Survivors Widow(er)s and parents_x  Survivors Children_x  \
# 0                           4884520.0             1437963.0
# 1                               849.0                 322.0
# 2                              3694.0                1005.0
# 3                               499.0                 186.0
# 4                               459.0                 202.0
#
#    Disability Disabled workers_x  ...  Retirement Retired workers_y  \
# 0                      8759959.0  ...                    34593080.0
# 1                         2221.0  ...                        5540.0
# 2                         7164.0  ...                       27340.0
# 3                         1633.0  ...                        3440.0
# 4                         1442.0  ...                        2360.0
#
#    Retirement Spouses_y  Retirement Children_y  \
# 0             2316536.0               579859.0
# 1                 385.0                   95.0
# 2                1745.0                  415.0
# 3                 195.0                   65.0
# 4                 175.0                   55.0
#
#    Survivors Widow(er)s and parents_y  Survivors Children_y  \
# 0                           4445547.0             1912789.0
# 1                               845.0                 435.0
# 2                              3290.0                1310.0
# 3                               570.0                 305.0
# 4                               505.0                 280.0
#
#    Disability Disabled workers_y  Disability Spouses_y  Disability Children_y  \
# 0                      8203951.0              160300.0              1819906.0
# 1                         2115.0                  45.0                  590.0
# 2                         6455.0                 140.0                 1365.0
# 3                         1640.0                  35.0                  420.0
# 4                         1400.0                  30.0                  375.0
#
#    Aged 65 or older Men_y  Aged 65 or older Women_y
# 0              16195967.0                21095605.0
# 1                  2595.0                    3430.0
# 2                 12970.0                   15610.0
# 3                  1625.0                    2130.0
# 4                  1155.0                    1525.0
#
# [5 rows x 26 columns]

# %%
# Rename columns in df_2010
df_2010.columns = ['State or area', 'County', 'ANSI Code_amount', 'Total_amount', 
        'Retirement Retired workers_amount', 'Retirement Spouses_amount',
        'Retirement Children_amount', 'Survivors Widow(er)s and parents_amount',
       'Survivors Children_amount', 'Disability Disabled workers_amount',
       'Disability Spouses_amount', 'Disability Children_amount',
       'Aged 65 or older Men_amount', 'Aged 65 or older Women_amount', 'ANSI Code_people',
       'Total_people', 'Retirement Retired workers_people', 'Retirement Spouses_people',
       'Retirement Children_people', 'Survivors Widow(er)s and parents_people',
       'Survivors Children_people', 'Disability Disabled workers_people',
       'Disability Spouses_people', 'Disability Children_people',
       'Aged 65 or older Men_people', 'Aged 65 or older Women_people']

# %%
# Rename columns in df_2015
df_2015.columns = ['State or area', 'County', 'ANSI Code_amount', 'Total_amount', 
        'Retirement Retired workers_amount', 'Retirement Spouses_amount',
        'Retirement Children_amount', 'Survivors Widow(er)s and parents_amount',
       'Survivors Children_amount', 'Disability Disabled workers_amount',
       'Disability Spouses_amount', 'Disability Children_amount',
       'Aged 65 or older Men_amount', 'Aged 65 or older Women_amount', 'ANSI Code_people',
       'Total_people', 'Retirement Retired workers_people', 'Retirement Spouses_people',
       'Retirement Children_people', 'Survivors Widow(er)s and parents_people',
       'Survivors Children_people', 'Disability Disabled workers_people',
       'Disability Spouses_people', 'Disability Children_people',
       'Aged 65 or older Men_people', 'Aged 65 or older Women_people']

# %%
# Rename columns in df_2020
df_2020.columns = ['State or area', 'County', 'ANSI Code_amount', 'Total_amount', 
        'Retirement Retired workers_amount', 'Retirement Spouses_amount',
        'Retirement Children_amount', 'Survivors Widow(er)s and parents_amount',
       'Survivors Children_amount', 'Disability Disabled workers_amount',
       'Disability Spouses_amount', 'Disability Children_amount',
       'Aged 65 or older Men_amount', 'Aged 65 or older Women_amount', 'ANSI Code_people',
       'Total_people', 'Retirement Retired workers_people', 'Retirement Spouses_people',
       'Retirement Children_people', 'Survivors Widow(er)s and parents_people',
       'Survivors Children_people', 'Disability Disabled workers_people',
       'Disability Spouses_people', 'Disability Children_people',
       'Aged 65 or older Men_people', 'Aged 65 or older Women_people']

# %%
# Sum of NaN values in df_2010
df_2010.isna().sum()
# Out:
# State or area                              0
# County                                     7
# ANSI Code_amount                           3
# Total_amount                               0
# Retirement Retired workers_amount          0
# Retirement Spouses_amount                  0
# Retirement Children_amount                 0
# Survivors Widow(er)s and parents_amount    0
# Survivors Children_amount                  0
# Disability Disabled workers_amount         0
# Disability Spouses_amount                  0
# Disability Children_amount                 0
# Aged 65 or older Men_amount                0
# Aged 65 or older Women_amount              0
# ANSI Code_people                           3
# Total_people                               1
# Retirement Retired workers_people          1
# Retirement Spouses_people                  1
# Retirement Children_people                 1
# Survivors Widow(er)s and parents_people    1
# Survivors Children_people                  1
# Disability Disabled workers_people         1
# Disability Spouses_people                  1
# Disability Children_people                 1
# Aged 65 or older Men_people                1
# Aged 65 or older Women_people              1
# dtype: int64

# %%
# Sum of NaN values in df_2015
df_2015.isna().sum()
# Out:
# State or area                              0
# County                                     7
# ANSI Code_amount                           4
# Total_amount                               1
# Retirement Retired workers_amount          1
# Retirement Spouses_amount                  1
# Retirement Children_amount                 1
# Survivors Widow(er)s and parents_amount    1
# Survivors Children_amount                  1
# Disability Disabled workers_amount         1
# Disability Spouses_amount                  1
# Disability Children_amount                 1
# Aged 65 or older Men_amount                1
# Aged 65 or older Women_amount              1
# ANSI Code_people                           4
# Total_people                               1
# Retirement Retired workers_people          1
# Retirement Spouses_people                  1
# Retirement Children_people                 1
# Survivors Widow(er)s and parents_people    1
# Survivors Children_people                  1
# Disability Disabled workers_people         1
# Disability Spouses_people                  1
# Disability Children_people                 1
# Aged 65 or older Men_people                1
# Aged 65 or older Women_people              1
# dtype: int64

# %%
# Sum of NaN values in df_2020
df_2020.isna().sum()
# Out:
# State or area                               0
# County                                     10
# ANSI Code_amount                           14
# Total_amount                               11
# Retirement Retired workers_amount          11
# Retirement Spouses_amount                  11
# Retirement Children_amount                 11
# Survivors Widow(er)s and parents_amount    11
# Survivors Children_amount                  11
# Disability Disabled workers_amount         11
# Disability Spouses_amount                  11
# Disability Children_amount                 11
# Aged 65 or older Men_amount                11
# Aged 65 or older Women_amount              11
# ANSI Code_people                           13
# Total_people                               10
# Retirement Retired workers_people          10
# Retirement Spouses_people                  10
# Retirement Children_people                 10
# Survivors Widow(er)s and parents_people    10
# Survivors Children_people                  10
# Disability Disabled workers_people         10
# Disability Spouses_people                  10
# Disability Children_people                 10
# Aged 65 or older Men_people                10
# Aged 65 or older Women_people              10
# dtype: int64

# %%
# Display NaN values in df_2010
df_2010[df_2010['County'].isna()]
# Out:
#                      State or area County  ANSI Code_amount  Total_amount  \
# 0                    United States    NaN               NaN    58048295.0
# 320           District of Columbia    NaN           11000.0       72460.0
# 3158                Outlying areas    NaN               NaN           0.0
# 3159                American Samoa    NaN           60000.0        3656.0
# 3160                          Guam    NaN           66000.0        9918.0
# 3161  Northern Mariana\n   Islands    NaN           69000.0        1346.0
# 3243             Foreign countries    NaN               NaN      320754.0
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            40662492.0                  1343640.0
# 320                             50851.0                     1029.0
# 3158                                0.0                        0.0
# 3159                             1481.0                       61.0
# 3160                             6098.0                      353.0
# 3161                              768.0                       36.0
# 3243                           209415.0                    22312.0
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       334405.0                                4884520.0
# 320                        444.0                                   4985.0
# 3158                         0.0                                      0.0
# 3159                       125.0                                    377.0
# 3160                       205.0                                    991.0
# 3161                        72.0                                    146.0
# 3243                      3925.0                                  60530.0
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1437963.0                           8759959.0  ...
# 320                      2382.0                             12201.0  ...
# 3158                        0.0                                 0.0  ...
# 3159                      406.0                              1056.0  ...
# 3160                      763.0                              1360.0  ...
# 3161                      152.0                               159.0  ...
# 3243                    10099.0                             13066.0  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            34593080.0                  2316536.0
# 320                             48173.0                     1723.0
# 3158                                NaN                        NaN
# 3159                             1925.0                      190.0
# 3160                             7742.0                      979.0
# 3161                             1179.0                      124.0
# 3243                           333247.0                    86030.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       579859.0                                4445547.0
# 320                        826.0                                   5283.0
# 3158                         NaN                                      NaN
# 3159                       352.0                                    586.0
# 3160                       543.0                                   1339.0
# 3161                       257.0                                    289.0
# 3243                      9740.0                                  86594.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1912789.0                           8203951.0
# 320                      3731.0                             12843.0
# 3158                        NaN                                 NaN
# 3159                      902.0                              1271.0
# 3160                     1388.0                              1490.0
# 3161                      348.0                               226.0
# 3243                    15248.0                             13349.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      160300.0                   1819906.0
# 320                        35.0                      1803.0
# 3158                        NaN                         NaN
# 3159                       60.0                       765.0
# 3160                       64.0                       580.0
# 3161                       10.0                        79.0
# 3243                      614.0                      3493.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      16195967.0                     21095605.0
# 320                       21377.0                        30505.0
# 3158                          NaN                            NaN
# 3159                       1071.0                         1152.0
# 3160                       4195.0                         4338.0
# 3161                        629.0                          543.0
# 3243                     219907.0                       247957.0
#
# [7 rows x 26 columns]

# %%
# Display NaN values in df_2015
df_2015[df_2015['County'].isna()]
# Out:
#                  State or area County  ANSI Code_amount  Total_amount  \
# 0                United States    NaN               NaN    73642029.0
# 3155            Outlying areas    NaN               NaN           NaN
# 3156            American Samoa    NaN           60000.0        4338.0
# 3157                      Guam    NaN           66000.0       13555.0
# 3158  Northern Mariana Islands    NaN           69000.0        1742.0
# 3240         Foreign countries    NaN               NaN      402455.0
# 3241                   Unknown    NaN               NaN        2318.0
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            53790278.0                  1612415.0
# 3155                                NaN                        NaN
# 3156                             1999.0                       79.0
# 3157                             8950.0                      455.0
# 3158                             1061.0                       42.0
# 3240                           272517.0                    29706.0
# 3241                             1787.0                       46.0
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       422191.0                                5194659.0
# 3155                         NaN                                      NaN
# 3156                       108.0                                    447.0
# 3157                       259.0                                   1230.0
# 3158                        71.0                                    194.0
# 3240                      5265.0                                  70326.0
# 3241                         8.0                                    252.0
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1575147.0                          10386494.0  ...
# 3155                        NaN                                 NaN  ...
# 3156                      400.0                              1162.0  ...
# 3157                      804.0                              1694.0  ...
# 3158                      164.0                               195.0  ...
# 3240                    11155.0                             12000.0  ...
# 3241                       35.0                               181.0  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            40089061.0                  2335807.0
# 3155                                NaN                        NaN
# 3156                             2277.0                      208.0
# 3157                             9919.0                     1057.0
# 3158                             1489.0                      116.0
# 3240                           390368.0                   104546.0
# 3241                             1363.0                       75.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       648530.0                                4190676.0
# 3155                         NaN                                      NaN
# 3156                       278.0                                    607.0
# 3157                       602.0                                   1472.0
# 3158                       186.0                                    311.0
# 3240                     10851.0                                  92364.0
# 3241                        12.0                                    215.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1892885.0                           8909430.0
# 3155                        NaN                                 NaN
# 3156                      804.0                              1331.0
# 3157                     1291.0                              1642.0
# 3158                      315.0                               249.0
# 3240                    14608.0                             10773.0
# 3241                       38.0                               142.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      141760.0                   1755276.0
# 3155                        NaN                         NaN
# 3156                       54.0                       677.0
# 3157                       67.0                       578.0
# 3158                       10.0                        74.0
# 3240                      529.0                      3191.0
# 3241                        3.0                        26.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      19144628.0                     24098571.0
# 3155                          NaN                            NaN
# 3156                       1221.0                         1348.0
# 3157                       5283.0                         5651.0
# 3158                        799.0                          723.0
# 3240                     264860.0                       290151.0
# 3241                        784.0                          817.0
#
# [7 rows x 26 columns]

# %%
# Display NaN values in df_2020
df_2020[df_2020['County'].isna()]
# Out:
#                      State or area County  ANSI Code_amount  Total_amount  \
# 0                    United States    NaN               NaN    58048295.0
# 320           District of Columbia    NaN           11000.0       72460.0
# 3156                Outlying areas    NaN               NaN           0.0
# 3157                American Samoa    NaN           60000.0        3656.0
# 3158                          Guam    NaN           66000.0        9918.0
# 3159  Northern Mariana\n   Islands    NaN           69000.0        1346.0
# 3241             Foreign countries    NaN               NaN      320754.0
# 3250                Outlying areas    NaN               NaN           NaN
# 3251      Northern Mariana Islands    NaN               NaN           NaN
# 3252                       Unknown    NaN               NaN           NaN
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            40662492.0                  1343640.0
# 320                             50851.0                     1029.0
# 3156                                0.0                        0.0
# 3157                             1481.0                       61.0
# 3158                             6098.0                      353.0
# 3159                              768.0                       36.0
# 3241                           209415.0                    22312.0
# 3250                                NaN                        NaN
# 3251                                NaN                        NaN
# 3252                                NaN                        NaN
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       334405.0                                4884520.0
# 320                        444.0                                   4985.0
# 3156                         0.0                                      0.0
# 3157                       125.0                                    377.0
# 3158                       205.0                                    991.0
# 3159                        72.0                                    146.0
# 3241                      3925.0                                  60530.0
# 3250                         NaN                                      NaN
# 3251                         NaN                                      NaN
# 3252                         NaN                                      NaN
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1437963.0                           8759959.0  ...
# 320                      2382.0                             12201.0  ...
# 3156                        0.0                                 0.0  ...
# 3157                      406.0                              1056.0  ...
# 3158                      763.0                              1360.0  ...
# 3159                      152.0                               159.0  ...
# 3241                    10099.0                             13066.0  ...
# 3250                        NaN                                 NaN  ...
# 3251                        NaN                                 NaN  ...
# 3252                        NaN                                 NaN  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            46329595.0                  2324030.0
# 320                                 NaN                        NaN
# 3156                                NaN                        NaN
# 3157                             2629.0                      189.0
# 3158                            12566.0                     1065.0
# 3159                                NaN                        NaN
# 3241                           441268.0                   115815.0
# 3250                                NaN                        NaN
# 3251                             2010.0                      133.0
# 3252                              717.0                       41.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       704207.0                                3938577.0
# 320                          NaN                                      NaN
# 3156                         NaN                                      NaN
# 3157                       224.0                                    596.0
# 3158                       522.0                                   1565.0
# 3159                         NaN                                      NaN
# 3241                     11693.0                                  99618.0
# 3250                         NaN                                      NaN
# 3251                       167.0                                    314.0
# 3252                         7.0                                    108.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1936071.0                           8151016.0
# 320                         NaN                                 NaN
# 3156                        NaN                                 NaN
# 3157                      671.0                              1271.0
# 3158                     1199.0                              1548.0
# 3159                        NaN                                 NaN
# 3241                    13420.0                              8869.0
# 3250                        NaN                                 NaN
# 3251                      323.0                               281.0
# 3252                       19.0                                81.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      104014.0                   1363357.0
# 320                         NaN                         NaN
# 3156                        NaN                         NaN
# 3157                       39.0                       480.0
# 3158                       61.0                       506.0
# 3159                        NaN                         NaN
# 3241                      395.0                      2843.0
# 3250                        NaN                         NaN
# 3251                        6.0                        76.0
# 3252                        1.0                        22.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      22310264.0                     27516391.0
# 320                           NaN                            NaN
# 3156                          NaN                            NaN
# 3157                       1378.0                         1508.0
# 3158                       6533.0                         7027.0
# 3159                          NaN                            NaN
# 3241                     303252.0                       328949.0
# 3250                          NaN                            NaN
# 3251                       1041.0                          990.0
# 3252                        387.0                          451.0
#
# [10 rows x 26 columns]

# %%
# Drop outlying areas in df_2010
df_2010.drop(df_2010[df_2010['State or area'].str.contains('Outlying areas')].index, inplace=True)

# %%
# Display clean DataFrame for df_2010
df_2010[df_2010['County'].isna()]
# Out:
#                      State or area County  ANSI Code_amount  Total_amount  \
# 0                    United States    NaN               NaN    58048295.0
# 320           District of Columbia    NaN           11000.0       72460.0
# 3159                American Samoa    NaN           60000.0        3656.0
# 3160                          Guam    NaN           66000.0        9918.0
# 3161  Northern Mariana\n   Islands    NaN           69000.0        1346.0
# 3243             Foreign countries    NaN               NaN      320754.0
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            40662492.0                  1343640.0
# 320                             50851.0                     1029.0
# 3159                             1481.0                       61.0
# 3160                             6098.0                      353.0
# 3161                              768.0                       36.0
# 3243                           209415.0                    22312.0
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       334405.0                                4884520.0
# 320                        444.0                                   4985.0
# 3159                       125.0                                    377.0
# 3160                       205.0                                    991.0
# 3161                        72.0                                    146.0
# 3243                      3925.0                                  60530.0
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1437963.0                           8759959.0  ...
# 320                      2382.0                             12201.0  ...
# 3159                      406.0                              1056.0  ...
# 3160                      763.0                              1360.0  ...
# 3161                      152.0                               159.0  ...
# 3243                    10099.0                             13066.0  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            34593080.0                  2316536.0
# 320                             48173.0                     1723.0
# 3159                             1925.0                      190.0
# 3160                             7742.0                      979.0
# 3161                             1179.0                      124.0
# 3243                           333247.0                    86030.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       579859.0                                4445547.0
# 320                        826.0                                   5283.0
# 3159                       352.0                                    586.0
# 3160                       543.0                                   1339.0
# 3161                       257.0                                    289.0
# 3243                      9740.0                                  86594.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1912789.0                           8203951.0
# 320                      3731.0                             12843.0
# 3159                      902.0                              1271.0
# 3160                     1388.0                              1490.0
# 3161                      348.0                               226.0
# 3243                    15248.0                             13349.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      160300.0                   1819906.0
# 320                        35.0                      1803.0
# 3159                       60.0                       765.0
# 3160                       64.0                       580.0
# 3161                       10.0                        79.0
# 3243                      614.0                      3493.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      16195967.0                     21095605.0
# 320                       21377.0                        30505.0
# 3159                       1071.0                         1152.0
# 3160                       4195.0                         4338.0
# 3161                        629.0                          543.0
# 3243                     219907.0                       247957.0
#
# [6 rows x 26 columns]

# %%
# Drop outlying areas in df_2015
df_2015.drop(df_2015[df_2015['State or area'].str.contains('Outlying areas')].index, inplace=True)

# %%
# Display clean DataFrame for df_2015
df_2015[df_2015['County'].isna()]
# Out:
#                  State or area County  ANSI Code_amount  Total_amount  \
# 0                United States    NaN               NaN    73642029.0
# 3156            American Samoa    NaN           60000.0        4338.0
# 3157                      Guam    NaN           66000.0       13555.0
# 3158  Northern Mariana Islands    NaN           69000.0        1742.0
# 3240         Foreign countries    NaN               NaN      402455.0
# 3241                   Unknown    NaN               NaN        2318.0
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            53790278.0                  1612415.0
# 3156                             1999.0                       79.0
# 3157                             8950.0                      455.0
# 3158                             1061.0                       42.0
# 3240                           272517.0                    29706.0
# 3241                             1787.0                       46.0
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       422191.0                                5194659.0
# 3156                       108.0                                    447.0
# 3157                       259.0                                   1230.0
# 3158                        71.0                                    194.0
# 3240                      5265.0                                  70326.0
# 3241                         8.0                                    252.0
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1575147.0                          10386494.0  ...
# 3156                      400.0                              1162.0  ...
# 3157                      804.0                              1694.0  ...
# 3158                      164.0                               195.0  ...
# 3240                    11155.0                             12000.0  ...
# 3241                       35.0                               181.0  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            40089061.0                  2335807.0
# 3156                             2277.0                      208.0
# 3157                             9919.0                     1057.0
# 3158                             1489.0                      116.0
# 3240                           390368.0                   104546.0
# 3241                             1363.0                       75.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       648530.0                                4190676.0
# 3156                       278.0                                    607.0
# 3157                       602.0                                   1472.0
# 3158                       186.0                                    311.0
# 3240                     10851.0                                  92364.0
# 3241                        12.0                                    215.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1892885.0                           8909430.0
# 3156                      804.0                              1331.0
# 3157                     1291.0                              1642.0
# 3158                      315.0                               249.0
# 3240                    14608.0                             10773.0
# 3241                       38.0                               142.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      141760.0                   1755276.0
# 3156                       54.0                       677.0
# 3157                       67.0                       578.0
# 3158                       10.0                        74.0
# 3240                      529.0                      3191.0
# 3241                        3.0                        26.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      19144628.0                     24098571.0
# 3156                       1221.0                         1348.0
# 3157                       5283.0                         5651.0
# 3158                        799.0                          723.0
# 3240                     264860.0                       290151.0
# 3241                        784.0                          817.0
#
# [6 rows x 26 columns]

# %%
# Drop outlying areas in df_2020
df_2020.drop(df_2020[df_2020['State or area'].str.contains('Outlying areas')].index, inplace=True)

# %%
# Display clean DataFrame for df_2020
df_2020[df_2020['County'].isna()]
# Out:
#                      State or area County  ANSI Code_amount  Total_amount  \
# 0                    United States    NaN               NaN    58048295.0
# 320           District of Columbia    NaN           11000.0       72460.0
# 3157                American Samoa    NaN           60000.0        3656.0
# 3158                          Guam    NaN           66000.0        9918.0
# 3159  Northern Mariana\n   Islands    NaN           69000.0        1346.0
# 3241             Foreign countries    NaN               NaN      320754.0
# 3251      Northern Mariana Islands    NaN               NaN           NaN
# 3252                       Unknown    NaN               NaN           NaN
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                            40662492.0                  1343640.0
# 320                             50851.0                     1029.0
# 3157                             1481.0                       61.0
# 3158                             6098.0                      353.0
# 3159                              768.0                       36.0
# 3241                           209415.0                    22312.0
# 3251                                NaN                        NaN
# 3252                                NaN                        NaN
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                       334405.0                                4884520.0
# 320                        444.0                                   4985.0
# 3157                       125.0                                    377.0
# 3158                       205.0                                    991.0
# 3159                        72.0                                    146.0
# 3241                      3925.0                                  60530.0
# 3251                         NaN                                      NaN
# 3252                         NaN                                      NaN
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                     1437963.0                           8759959.0  ...
# 320                      2382.0                             12201.0  ...
# 3157                      406.0                              1056.0  ...
# 3158                      763.0                              1360.0  ...
# 3159                      152.0                               159.0  ...
# 3241                    10099.0                             13066.0  ...
# 3251                        NaN                                 NaN  ...
# 3252                        NaN                                 NaN  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 0                            46329595.0                  2324030.0
# 320                                 NaN                        NaN
# 3157                             2629.0                      189.0
# 3158                            12566.0                     1065.0
# 3159                                NaN                        NaN
# 3241                           441268.0                   115815.0
# 3251                             2010.0                      133.0
# 3252                              717.0                       41.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                       704207.0                                3938577.0
# 320                          NaN                                      NaN
# 3157                       224.0                                    596.0
# 3158                       522.0                                   1565.0
# 3159                         NaN                                      NaN
# 3241                     11693.0                                  99618.0
# 3251                       167.0                                    314.0
# 3252                         7.0                                    108.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 0                     1936071.0                           8151016.0
# 320                         NaN                                 NaN
# 3157                      671.0                              1271.0
# 3158                     1199.0                              1548.0
# 3159                        NaN                                 NaN
# 3241                    13420.0                              8869.0
# 3251                      323.0                               281.0
# 3252                       19.0                                81.0
#
#       Disability Spouses_people  Disability Children_people  \
# 0                      104014.0                   1363357.0
# 320                         NaN                         NaN
# 3157                       39.0                       480.0
# 3158                       61.0                       506.0
# 3159                        NaN                         NaN
# 3241                      395.0                      2843.0
# 3251                        6.0                        76.0
# 3252                        1.0                        22.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                      22310264.0                     27516391.0
# 320                           NaN                            NaN
# 3157                       1378.0                         1508.0
# 3158                       6533.0                         7027.0
# 3159                          NaN                            NaN
# 3241                     303252.0                       328949.0
# 3251                       1041.0                          990.0
# 3252                        387.0                          451.0
#
# [8 rows x 26 columns]

# %% [markdown]
# # What is the trend of social security payout overtime? (2010-2020)

# %% [markdown]
# ## 2010 Breakdown by States

# %% [markdown]
# ### Total Amounts

# %%
# Total amount of benefits grouped by State for 2010
states_amount_2010 = df_2010.groupby(['State or area'])['Total_amount'].sum()

# %% [markdown]
# ### Total Number of People

# %%
# Total number of beneficiaries grouped by State for 2010
states_people_2010 = df_2010.groupby(['State or area'])['Total_people'].sum()

# %% [markdown]
# ### Correlation between the amount of benefits and the number of beneficiaries

# %%
# Correlation between amount of benefits and number of beneficiaries 2010
correlation_df_2010 = pd.merge(states_people_2010, states_amount_2010, on="State or area", how="right")

# Correlation graph between amount of benefits and number of beneficiaries for 2010
people_2010 = correlation_df_2010.iloc[:,0]
amount_2010 = correlation_df_2010.iloc[:,1]
(slope, intercept, rvalue, pvalue, stderr) = linregress(people_2010, amount_2010)
regress_values = people_2010 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(people_2010,amount_2010)
plt.figure(figsize=(8,5))
plt.scatter(people_2010,amount_2010)
plt.plot(people_2010, amount_2010, "r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")
plt.title('2010 Amount of Benefits and the Number of Beneficiaries')
plt.xlabel('Total Amount by State (in thousands)')
plt.ylabel('Total Number of Beneficiaries by State (in thousands)')
print(f"The correlation between both factors is {round(correlation[0],2)}")

# Save the figure
plt.savefig("output_data/Correlation_2010.png")

# Show graph
plt.show()
# Out:
# The correlation between both factors is 1.0

# %% [markdown]
# ## 2015 Breakdown by States

# %% [markdown]
# ### Total Amounts

# %%
# Total amount of benefits grouped by State for 2015
states_amount_2015 = df_2015.groupby(['State or area'])['Total_amount'].sum()

# %% [markdown]
# ### Total Number of People

# %%
# Total number of beneficiaries grouped by State for 2015
states_people_2015 = df_2015.groupby(['State or area'])['Total_people'].sum()

# Correlation between amount of benefits and number of beneficiaries 2015
correlation_df_2015 = pd.merge(states_people_2015, states_amount_2015, on="State or area", how="right")

# %% [markdown]
# ### Correlation between the amount of benefits and the number of beneficiaries

# %%
# Correlation graph between amount of benefits and number of beneficiaries for 2015
people_2015 = correlation_df_2015.iloc[:,0]
amount_2015 = correlation_df_2015.iloc[:,1]
(slope, intercept, rvalue, pvalue, stderr) = linregress(people_2015, amount_2015)
regress_values = people_2015 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(people_2015,amount_2015)
plt.figure(figsize=(8,5))
plt.scatter(people_2015,amount_2015)
plt.plot(people_2015, amount_2015, "r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")
plt.title('2015 Amount of Benefits and the Number of Beneficiaries')
plt.xlabel('Total Amount by State (in thousands)')
plt.ylabel('Total Number of Beneficiaries by State (in thousands)')
print(f"The correlation between both factors is {round(correlation[0],2)}")

# Save the figure
plt.savefig("output_data/Correlation_2015.png")

# Show graph
plt.show()
# Out:
# The correlation between both factors is 1.0

# %% [markdown]
# ## 2020 Breakdown by States

# %% [markdown]
# ### Total Amounts

# %%
# Total amount of benefits grouped by State for 2020
states_amount_2020 = df_2020.groupby(['State or area'])['Total_amount'].sum()

# %% [markdown]
# ### Total Number of People

# %%
# Total number of beneficiaries grouped by State for 2020
states_people_2020 = df_2020.groupby(['State or area'])['Total_people'].sum()

# %% [markdown]
# ### Correlation between the amount of benefits and the number of beneficiaries

# %%
# Correlation between amount of benefits and number of beneficiaries 2020
correlation_df_2020 = pd.merge(states_people_2020, states_amount_2020, on="State or area", how="right")

# Correlation between amount of benefits and number of beneficiaries 2020
people_2020 = correlation_df_2020.iloc[:,0]
amount_2020 = correlation_df_2020.iloc[:,1]
(slope, intercept, rvalue, pvalue, stderr) = linregress(people_2020, amount_2020)
regress_values = people_2020 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(people_2020,amount_2020)
plt.figure(figsize=(8,5))
plt.scatter(people_2020,amount_2020)
plt.plot(people_2020, amount_2020, "r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")
plt.title('2020 Amount of Benefits and the Number of Beneficiaries')
plt.xlabel('Total Amount by State (in thousands)')
plt.ylabel('Total Number of Beneficiaries by State (in thousands)')
print(f"The correlation between both factors is {round(correlation[0],2)}")

# Save the figure
plt.savefig("output_data/Correlation_2020.png")

# Show graph
plt.show()
# Out:
# The correlation between both factors is 1.0

# %% [markdown]
# ## Average Payout Overtime

# %%
# Average Payout Overtime
a_amount_2010 =df_2010['Total_amount'].sum()
a_people_2010=df_2010['Total_people'].sum()
average_payout_2010 = a_amount_2010/a_people_2010
average_payout_2010=average_payout_2010*1000

# Average Payout Overtime 2015
a_amount_2015 =df_2015['Total_amount'].sum()
a_people_2015=df_2015['Total_people'].sum()
average_payout_2015 = a_amount_2015/a_people_2015
average_payout_2015=average_payout_2015*1000

# Average Payout Overtime 2020
a_amount_2020 =df_2020['Total_amount'].sum()
a_people_2020=df_2020['Total_people'].sum()
average_payout_2020 = a_amount_2020/a_people_2020
average_payout_2020 = average_payout_2020*1000

# %%
# Average payout DataFrame
average_df = pd.DataFrame(
    {"Average Payout": [average_payout_2010,average_payout_2015,average_payout_2020]}, 
    index=['2010','2015','2020'])
average_df
# Out:
#       Average Payout
# 2010     1074.663328
# 2015     1228.530419
# 2020      895.557122

# %%
# Average payout bar graph
average_df.plot(kind='bar', facecolor='blue', figsize=(8,4), title='Average Payout Over a Decade')
plt.xlabel('Year')
plt.ylabel('Average Payout')

# Save the figure
plt.savefig("output_data/Average_payout_q1.png")

# Show graph
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Minnesota Average Payout Trend

# %%
# Minnesota average payout 2010
amt_2010mn=df_2010.loc[df_2010['State or area']=='Minnesota']['Total_amount'].sum()
ppl_2010mn=df_2010.loc[df_2010['State or area']=='Minnesota']['Total_people'].sum()
avg_2010mn=amt_2010mn/ppl_2010mn*1000

# Minnesota average payout 2015
amt_2015mn=df_2015.loc[df_2015['State or area']=='Minnesota']['Total_amount'].sum()
ppl_2015mn=df_2015.loc[df_2015['State or area']=='Minnesota']['Total_people'].sum()
avg_2015mn=amt_2015mn/ppl_2015mn*1000

# Minnesota average payout 2020
amt_2020mn=df_2020.loc[df_2020['State or area']=='Minnesota']['Total_amount'].sum()
ppl_2020mn=df_2020.loc[df_2020['State or area']=='Minnesota']['Total_people'].sum()
avg_2020mn=amt_2020mn/ppl_2020mn*1000

# Minnesota average DataFrame
average_df_mn = pd.DataFrame(
    {"Minnesota Average Payout": [avg_2010mn,avg_2015mn,avg_2020mn]}, 
    index=['2010','2015','2020'])
average_df_mn
# Out:
#       Minnesota Average Payout
# 2010               1108.038214
# 2015               1281.452374
# 2020                913.856306

# %%
# Average payout bar graph - Minnesota
average_df_mn.plot(kind='bar', facecolor='blue', figsize=(8,4), title='Minnesota Average Payout Over a Decade')
plt.xlabel('Year')
plt.ylabel('Average Payout')

# Save the figure
plt.savefig("output_data/Average_payout_mn_q1.png")

# Show graph
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Wisconsin Average Payout

# %%
# Minnesota average payout 2010
amt_2010wi=df_2010.loc[df_2010['State or area']=='Wisconsin']['Total_amount'].sum()
ppl_2010wi=df_2010.loc[df_2010['State or area']=='Wisconsin']['Total_people'].sum()
avg_2010wi=amt_2010wi/ppl_2010wi*1000

# Minnesota average payout 2015
amt_2015wi=df_2015.loc[df_2015['State or area']=='Wisconsin']['Total_amount'].sum()
ppl_2015wi=df_2015.loc[df_2015['State or area']=='Wisconsin']['Total_people'].sum()
avg_2015wi=amt_2015wi/ppl_2015wi*1000

# Minnesota average payout 2020
amt_2020wi=df_2020.loc[df_2020['State or area']=='Wisconsin']['Total_amount'].sum()
ppl_2020wi=df_2020.loc[df_2020['State or area']=='Wisconsin']['Total_people'].sum()
avg_2020wi=amt_2020wi/ppl_2020wi*1000

# Minnesota average DataFrame
average_df_wi = pd.DataFrame(
    {"Wisconsin Average Payout": [avg_2010wi,avg_2015wi,avg_2020wi]}, 
    index=['2010','2015','2020'])
average_df_wi
# Out:
#       Wisconsin Average Payout
# 2010               1113.745643
# 2015               1274.658432
# 2020                926.571991

# %%
# Average payout bar graph - Wisonsin
average_df_wi.plot(kind='bar', facecolor='blue', figsize=(8,4), title='Wisconsin Average Payout Over a Decade')
plt.xlabel('Year')
plt.ylabel('Average Payout')

# Save the figure
plt.savefig("output_data/Average_payout_wi_q1.png")

# Show graph
plt.show()
plt.tight_layout()

# %% [markdown]
# # What is the average payout by states?

# %% [markdown]
# ## 2020 Average Payout by State

# %%
# Filtering to see only the 50 states in the data for 2020
fiftystates_2020 = df_2020.loc[df_2020['State or area'].isin(['Alabama', 'Alaska','Arizona','Arkansas','California','Colorado','Connecticut', 'Delaware', 'Florida','Georgia', 'Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland'
                                                             'Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey', 'New Mexico', 'New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon',
                                                             'Pennsylvania','Rhode Island', 'South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia', 'Wisconsin','Wyoming'])]
fiftystates_2020
# Out:
#      State or area         County  ANSI Code_amount  Total_amount  \
# 1          Alabama        Autauga            1001.0       10224.0
# 2          Alabama        Baldwin            1003.0       46097.0
# 3          Alabama        Barbour            1005.0        6213.0
# 4          Alabama           Bibb            1007.0        4960.0
# 5          Alabama         Blount            1009.0       12592.0
# ...            ...            ...               ...           ...
# 3244        Alaska       Kusilvak               NaN           NaN
# 3245        Alaska        Skagway               NaN           NaN
# 3246        Alaska       Wrangell               NaN           NaN
# 3248     Louisiana        LaSalle               NaN           NaN
# 3249  South Dakota  Oglala Lakota               NaN           NaN
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 1                                6352.0                      226.0
# 2                               32376.0                     1097.0
# 3                                3636.0                      107.0
# 4                                2608.0                       97.0
# 5                                7676.0                      318.0
# ...                                 ...                        ...
# 3244                                NaN                        NaN
# 3245                                NaN                        NaN
# 3246                                NaN                        NaN
# 3248                                NaN                        NaN
# 3249                                NaN                        NaN
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 1                           57.0                                    849.0
# 2                          251.0                                   3694.0
# 3                           31.0                                    499.0
# 4                           31.0                                    459.0
# 5                           74.0                                   1189.0
# ...                          ...                                      ...
# 3244                         NaN                                      NaN
# 3245                         NaN                                      NaN
# 3246                         NaN                                      NaN
# 3248                         NaN                                      NaN
# 3249                         NaN                                      NaN
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 1                         322.0                              2221.0  ...
# 2                        1005.0                              7164.0  ...
# 3                         186.0                              1633.0  ...
# 4                         202.0                              1442.0  ...
# 5                         320.0                              2787.0  ...
# ...                         ...                                 ...  ...
# 3244                        NaN                                 NaN  ...
# 3245                        NaN                                 NaN  ...
# 3246                        NaN                                 NaN  ...
# 3248                        NaN                                 NaN  ...
# 3249                        NaN                                 NaN  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 1                                7610.0                      280.0
# 2                               44075.0                     1670.0
# 3                                4415.0                      155.0
# 4                                3055.0                      140.0
# 5                                8815.0                      440.0
# ...                                 ...                        ...
# 3244                              410.0                       25.0
# 3245                              120.0                        5.0
# 3246                              450.0                       10.0
# 3248                             1910.0                      160.0
# 3249                              835.0                       30.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 1                          135.0                                    825.0
# 2                          530.0                                   3675.0
# 3                           85.0                                    480.0
# 4                           60.0                                    395.0
# 5                          145.0                                    995.0
# ...                          ...                                      ...
# 3244                        50.0                                     75.0
# 3245                         0.0                                     10.0
# 3246                         5.0                                     40.0
# 3248                        30.0                                    355.0
# 3249                        60.0                                    100.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 1                         480.0                              2455.0
# 2                        1555.0                              7520.0
# 3                         300.0                              1460.0
# 4                         275.0                              1270.0
# 5                         440.0                              2590.0
# ...                         ...                                 ...
# 3244                      150.0                                50.0
# 3245                        0.0                                 5.0
# 3246                        5.0                                40.0
# 3248                       85.0                               540.0
# 3249                      220.0                               245.0
#
#       Disability Spouses_people  Disability Children_people  \
# 1                          30.0                       485.0
# 2                         115.0                      1165.0
# 3                          15.0                       250.0
# 4                          20.0                       225.0
# 5                          50.0                       440.0
# ...                         ...                         ...
# 3244                        0.0                        25.0
# 3245                        0.0                         5.0
# 3246                        0.0                         5.0
# 3248                       15.0                        95.0
# 3249                        0.0                        50.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 1                          3525.0                         4635.0
# 2                         21020.0                        25280.0
# 3                          2105.0                         2660.0
# 4                          1515.0                         1850.0
# 5                          4300.0                         5315.0
# ...                           ...                            ...
# 3244                        230.0                          230.0
# 3245                         60.0                           65.0
# 3246                        260.0                          205.0
# 3248                       1040.0                         1230.0
# 3249                        380.0                          505.0
#
# [3121 rows x 26 columns]

# %%
#Average payout by state (in thousands)

states_amount_2020 = fiftystates_2020.groupby(['State or area'])['Total_amount'].mean()


states_rounded_2020 = states_amount_2020.round()
states_rounded_2020
# Out:
# State or area
# Alabama           15460.0
# Alaska             2755.0
# Arizona           79062.0
# Arkansas           8427.0
# California        92359.0
# Colorado          11706.0
# Connecticut       92861.0
# Delaware          66611.0
# Florida           61471.0
# Georgia            9751.0
# Hawaii            49787.0
# Idaho              6457.0
# Illinois          22245.0
# Indiana           14535.0
# Iowa               6402.0
# Kansas             5138.0
# Kentucky           7447.0
# Louisiana         12076.0
# Maine             18698.0
# Michigan          27232.0
# Minnesota         11238.0
# Mississippi        7122.0
# Missouri          12892.0
# Montana            3562.0
# Nebraska           3555.0
# Nevada            26520.0
# New Hampshire     28565.0
# New Jersey        84448.0
# New Mexico        10925.0
# New York          59754.0
# North Carolina    18816.0
# North Dakota       2297.0
# Ohio              25943.0
# Oklahoma           9463.0
# Oregon            21790.0
# Pennsylvania      42788.0
# Rhode Island      44350.0
# South Carolina    21546.0
# South Dakota       2361.0
# Tennessee         13804.0
# Texas             14003.0
# Utah              12097.0
# Vermont            9820.0
# Virginia          11370.0
# Washington        31533.0
# West Virginia      8366.0
# Wisconsin         16420.0
# Wyoming            4323.0
# Name: Total_amount, dtype: float64

# %%
#Create a dataframe

data= {'State': ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho',
                'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Michigan','Minnesota','Mississippi','Missouri','Montana',
                'Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma',
                 'Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington',
                 'West Virginia','Wisconsin','Wyoming'],
        'Average Payout':[15460, 2755, 79062, 8427, 92359, 11706, 92861, 66611, 61471, 9751, 48787, 6457, 22245, 14535, 6402, 5138, 7447, 12076,
                         18698, 27232, 11238, 7122, 12892, 3562, 3555, 26520, 28565, 84448, 10925, 59754, 18816, 2297, 25943, 9463, 21790, 42788,
                         44350, 21546, 2361, 13804, 14002, 12907, 9820, 11370, 31533, 8366, 16420, 4323]}

Average_payout_by_state_df = pd.DataFrame(data)
Average_payout_by_state_df
# Out:
#              State  Average Payout
# 0          Alabama           15460
# 1           Alaska            2755
# 2          Arizona           79062
# 3         Arkansas            8427
# 4       California           92359
# 5         Colorado           11706
# 6      Connecticut           92861
# 7         Delaware           66611
# 8          Florida           61471
# 9          Georgia            9751
# 10          Hawaii           48787
# 11           Idaho            6457
# 12        Illinois           22245
# 13         Indiana           14535
# 14            Iowa            6402
# 15          Kansas            5138
# 16        Kentucky            7447
# 17       Louisiana           12076
# 18           Maine           18698
# 19        Michigan           27232
# 20       Minnesota           11238
# 21     Mississippi            7122
# 22        Missouri           12892
# 23         Montana            3562
# 24        Nebraska            3555
# 25          Nevada           26520
# 26   New Hampshire           28565
# 27      New Jersey           84448
# 28      New Mexico           10925
# 29        New York           59754
# 30  North Carolina           18816
# 31    North Dakota            2297
# 32            Ohio           25943
# 33        Oklahoma            9463
# 34          Oregon           21790
# 35    Pennsylvania           42788
# 36    Rhode Island           44350
# 37  South Carolina           21546
# 38    South Dakota            2361
# 39       Tennessee           13804
# 40           Texas           14002
# 41            Utah           12907
# 42         Vermont            9820
# 43        Virginia           11370
# 44      Washington           31533
# 45   West Virginia            8366
# 46       Wisconsin           16420
# 47         Wyoming            4323

# %%
#statistical analysis

Average_payout_by_state_df.describe()
# Out:
#        Average Payout
# count       48.000000
# mean     24374.166667
# std      24773.692134
# min       2297.000000
# 25%       8411.750000
# 50%      13903.000000
# 75%      27565.250000
# max      92861.000000

# %%
# Graph 
# Setting x axis and tick locations

x_axis = np.arange(len(Average_payout_by_state_df))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(20,4))
plt.bar(x_axis, Average_payout_by_state_df["Average Payout"], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, Average_payout_by_state_df["State"], rotation="vertical")

plt.xlabel("State")
plt.ylabel("Average Payout in Thousands")
plt.title("2020 Average Payout by State")
plt.show()

# %% [raw]
# ## 2015 Average Payout by State

# %%
# Filtering to see only the 50 states in the data for 2015
fiftystates_2015 = df_2015.loc[df_2015['State or area'].isin(['Alabama', 'Alaska','Arizona','Arkansas','California','Colorado','Connecticut', 'Delaware', 'Florida','Georgia', 'Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland'
                                                             'Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey', 'New Mexico', 'New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon',
                                                             'Pennsylvania','Rhode Island', 'South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia', 'Wisconsin','Wyoming'])]
fiftystates_2015
# Out:
#      State or area      County  ANSI Code_amount  Total_amount  \
# 1          Alabama     Autauga            1001.0       13422.0
# 2          Alabama     Baldwin            1003.0       63848.0
# 3          Alabama     Barbour            1005.0        7664.0
# 4          Alabama        Bibb            1007.0        6226.0
# 5          Alabama      Blount            1009.0       16063.0
# ...            ...         ...               ...           ...
# 3150       Wyoming  Sweetwater           56037.0        8451.0
# 3151       Wyoming       Teton           56039.0        4290.0
# 3152       Wyoming       Uinta           56041.0        4244.0
# 3153       Wyoming    Washakie           56043.0        2410.0
# 3154       Wyoming      Weston           56045.0        2066.0
#
#       Retirement Retired workers_amount  Retirement Spouses_amount  \
# 1                                8726.0                      224.0
# 2                               46666.0                     1229.0
# 3                                4860.0                      120.0
# 4                                3544.0                      105.0
# 5                               10435.0                      318.0
# ...                                 ...                        ...
# 3150                             6129.0                      157.0
# 3151                             3637.0                      150.0
# 3152                             3015.0                      104.0
# 3153                             1897.0                       62.0
# 3154                             1569.0                       37.0
#
#       Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 1                           82.0                                    964.0
# 2                          315.0                                   4456.0
# 3                           36.0                                    529.0
# 4                           41.0                                    472.0
# 5                           85.0                                   1246.0
# ...                          ...                                      ...
# 3150                        33.0                                    597.0
# 3151                        26.0                                    234.0
# 3152                        23.0                                    320.0
# 3153                         7.0                                    160.0
# 3154                         6.0                                    181.0
#
#       Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 1                         390.0                              2827.0  ...
# 2                        1288.0                              9293.0  ...
# 3                         196.0                              1809.0  ...
# 4                         222.0                              1694.0  ...
# 5                         387.0                              3356.0  ...
# ...                         ...                                 ...  ...
# 3150                      263.0                              1199.0  ...
# 3151                       46.0                               189.0  ...
# 3152                      164.0                               587.0  ...
# 3153                       58.0                               214.0  ...
# 3154                       33.0                               227.0  ...
#
#       Retirement Retired workers_people  Retirement Spouses_people  \
# 1                                6605.0                      325.0
# 2                               34055.0                     1660.0
# 3                                4000.0                      185.0
# 4                                2775.0                      165.0
# 5                                8000.0                      490.0
# ...                                 ...                        ...
# 3150                             4095.0                      200.0
# 3151                             2350.0                      160.0
# 3152                             2100.0                      130.0
# 3153                             1435.0                       80.0
# 3154                             1160.0                       55.0
#
#       Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 1                          130.0                                    840.0
# 2                          440.0                                   3505.0
# 3                           70.0                                    515.0
# 4                           60.0                                    445.0
# 5                          145.0                                   1060.0
# ...                          ...                                      ...
# 3150                        50.0                                    415.0
# 3151                        35.0                                    160.0
# 3152                        30.0                                    235.0
# 3153                        10.0                                    120.0
# 3154                         5.0                                    140.0
#
#       Survivors Children_people  Disability Disabled workers_people  \
# 1                         485.0                              2450.0
# 2                        1465.0                              7625.0
# 3                         275.0                              1655.0
# 4                         280.0                              1490.0
# 5                         460.0                              2825.0
# ...                         ...                                 ...
# 3150                      290.0                               940.0
# 3151                       45.0                               150.0
# 3152                      190.0                               500.0
# 3153                       60.0                               190.0
# 3154                       35.0                               175.0
#
#       Disability Spouses_people  Disability Children_people  \
# 1                          25.0                       595.0
# 2                         130.0                      1460.0
# 3                          20.0                       330.0
# 4                          35.0                       380.0
# 5                          65.0                       620.0
# ...                         ...                         ...
# 3150                       20.0                       190.0
# 3151                        0.0                        20.0
# 3152                       10.0                        80.0
# 3153                        5.0                        30.0
# 3154                        0.0                        35.0
#
#       Aged 65 or older Men_people  Aged 65 or older Women_people
# 1                          3060.0                         4060.0
# 2                         16485.0                        19550.0
# 3                          1880.0                         2460.0
# 4                          1375.0                         1745.0
# 5                          3925.0                         4860.0
# ...                           ...                            ...
# 3150                       2010.0                         2170.0
# 3151                       1255.0                         1270.0
# 3152                       1035.0                         1150.0
# 3153                        730.0                          810.0
# 3154                        565.0                          675.0
#
# [3113 rows x 26 columns]

# %%
#Average payout by state (in thousands) 2015

states_amount_2015 = fiftystates_2015.groupby(['State or area'])['Total_amount'].mean()


states_rounded_2015 = states_amount_2015.round()
states_rounded_2015
# Out:
# State or area
# Alabama            19499.0
# Alaska              3724.0
# Arizona           105129.0
# Arkansas           10361.0
# California        119014.0
# Colorado           15821.0
# Connecticut       112706.0
# Delaware           87862.0
# Florida            80343.0
# Georgia            13035.0
# Hawaii             64172.0
# Idaho               8654.0
# Illinois           27042.0
# Indiana            18072.0
# Iowa                7829.0
# Kansas              6374.0
# Kentucky            9208.0
# Louisiana          15167.0
# Maine              23626.0
# Michigan           33581.0
# Minnesota          14431.0
# Mississippi         8913.0
# Missouri           15807.0
# Montana             4596.0
# Nebraska            4387.0
# Nevada             36079.0
# New Hampshire      37439.0
# New Jersey        103657.0
# New Mexico         14222.0
# New York           72555.0
# North Carolina     24490.0
# North Dakota        2804.0
# Ohio               31556.0
# Oklahoma           11681.0
# Oregon             28490.0
# Pennsylvania       52216.0
# Rhode Island       54402.0
# South Carolina     28695.0
# South Dakota        3011.0
# Tennessee          17645.0
# Texas              18352.0
# Utah               16149.0
# Vermont            12530.0
# Virginia           14974.0
# Washington         41809.0
# West Virginia      10083.0
# Wisconsin          20726.0
# Wyoming             5686.0
# Name: Total_amount, dtype: float64

# %%
#Create a dataframe

data_2015= {'State': ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Geiorgia','Hawaii','Idaho',
                'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Michigan','Minnesota','Mississippi','Missouri','Montana',
                'Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma',
                 'Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington',
                 'West Virginia','Wisconsin','Wyoming'],
        'Average Payout':[19499, 3724,105129, 10361, 119014, 15821, 112706, 87862, 80343, 13035, 64172, 8654, 27042, 18072, 7829, 6374, 9208, 15167, 23626,
                         33581, 14431, 8913, 15807, 4596, 4387, 36079, 37439, 103657, 14222, 72555, 24490, 2804, 31556, 11681, 28490, 52216, 54402,
                         28695, 3011, 17645, 18352, 16149, 12530, 14974, 41809, 10083, 20726, 5868]}

Average_payout_by_state_2015_df = pd.DataFrame(data_2015)
Average_payout_by_state_2015_df
# Out:
#              State  Average Payout
# 0          Alabama           19499
# 1           Alaska            3724
# 2          Arizona          105129
# 3         Arkansas           10361
# 4       California          119014
# 5         Colorado           15821
# 6      Connecticut          112706
# 7         Delaware           87862
# 8          Florida           80343
# 9         Geiorgia           13035
# 10          Hawaii           64172
# 11           Idaho            8654
# 12        Illinois           27042
# 13         Indiana           18072
# 14            Iowa            7829
# 15          Kansas            6374
# 16        Kentucky            9208
# 17       Louisiana           15167
# 18           Maine           23626
# 19        Michigan           33581
# 20       Minnesota           14431
# 21     Mississippi            8913
# 22        Missouri           15807
# 23         Montana            4596
# 24        Nebraska            4387
# 25          Nevada           36079
# 26   New Hampshire           37439
# 27      New Jersey          103657
# 28      New Mexico           14222
# 29        New York           72555
# 30  North Carolina           24490
# 31    North Dakota            2804
# 32            Ohio           31556
# 33        Oklahoma           11681
# 34          Oregon           28490
# 35    Pennsylvania           52216
# 36    Rhode Island           54402
# 37  South Carolina           28695
# 38    South Dakota            3011
# 39       Tennessee           17645
# 40           Texas           18352
# 41            Utah           16149
# 42         Vermont           12530
# 43        Virginia           14974
# 44      Washington           41809
# 45   West Virginia           10083
# 46       Wisconsin           20726
# 47         Wyoming            5868

# %%
#stat analysis 2015

Average_payout_by_state_2015_df.describe()
# Out:
#        Average Payout
# count       48.000000
# mean     31016.375000
# std      31406.259639
# min       2804.000000
# 25%      10291.500000
# 50%      17858.500000
# 75%      36419.000000
# max     119014.000000

# %%
# Graph 
# Setting x axis and tick locations

x_axis = np.arange(len(Average_payout_by_state_2015_df))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(20,4))
plt.bar(x_axis, Average_payout_by_state_df["Average Payout"], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, Average_payout_by_state_df["State"], rotation="vertical")

plt.xlabel("State")
plt.ylabel("Average Payout in Thousands")
plt.title("2015 Average Payout by State")
plt.show()

# %% [markdown]
# # What is the Average amount of payout per individual?

# %%
total_2015_payout_by_state = df_2015.groupby(["State or area"])['Total_amount'].sum()
total_2015_payout_by_state.head()
# Out:
# State or area
# Alabama           1306450.0
# Alaska             107985.0
# American Samoa       4338.0
# Arizona           1576938.0
# Arkansas           777067.0
# Name: Total_amount, dtype: float64

# %%
total_2010_payout_by_state = df_2010.groupby(["State or area"])['Total_amount'].sum()
total_2010_payout_by_state.head()
# Out:
# State or area
# Alabama           1035826.0
# Alaska              79907.0
# American Samoa       3656.0
# Arizona           1185927.0
# Arkansas           632019.0
# Name: Total_amount, dtype: float64

# %%
total_2020_payout_by_state = df_2020.groupby(["State or area"])['Total_amount'].sum()
total_2020_payout_by_state.head()
# Out:
# State or area
# Alabama           1035826.0
# Alaska              79907.0
# American Samoa       3656.0
# Arizona           1185927.0
# Arkansas           632019.0
# Name: Total_amount, dtype: float64

# %%
df_2015.head()
# Out:
#    State or area   County  ANSI Code_amount  Total_amount  \
# 0  United States      NaN               NaN    73642029.0
# 1        Alabama  Autauga            1001.0       13422.0
# 2        Alabama  Baldwin            1003.0       63848.0
# 3        Alabama  Barbour            1005.0        7664.0
# 4        Alabama     Bibb            1007.0        6226.0
#
#    Retirement Retired workers_amount  Retirement Spouses_amount  \
# 0                         53790278.0                  1612415.0
# 1                             8726.0                      224.0
# 2                            46666.0                     1229.0
# 3                             4860.0                      120.0
# 4                             3544.0                      105.0
#
#    Retirement Children_amount  Survivors Widow(er)s and parents_amount  \
# 0                    422191.0                                5194659.0
# 1                        82.0                                    964.0
# 2                       315.0                                   4456.0
# 3                        36.0                                    529.0
# 4                        41.0                                    472.0
#
#    Survivors Children_amount  Disability Disabled workers_amount  ...  \
# 0                  1575147.0                          10386494.0  ...
# 1                      390.0                              2827.0  ...
# 2                     1288.0                              9293.0  ...
# 3                      196.0                              1809.0  ...
# 4                      222.0                              1694.0  ...
#
#    Retirement Retired workers_people  Retirement Spouses_people  \
# 0                         40089061.0                  2335807.0
# 1                             6605.0                      325.0
# 2                            34055.0                     1660.0
# 3                             4000.0                      185.0
# 4                             2775.0                      165.0
#
#    Retirement Children_people  Survivors Widow(er)s and parents_people  \
# 0                    648530.0                                4190676.0
# 1                       130.0                                    840.0
# 2                       440.0                                   3505.0
# 3                        70.0                                    515.0
# 4                        60.0                                    445.0
#
#    Survivors Children_people  Disability Disabled workers_people  \
# 0                  1892885.0                           8909430.0
# 1                      485.0                              2450.0
# 2                     1465.0                              7625.0
# 3                      275.0                              1655.0
# 4                      280.0                              1490.0
#
#    Disability Spouses_people  Disability Children_people  \
# 0                   141760.0                   1755276.0
# 1                       25.0                       595.0
# 2                      130.0                      1460.0
# 3                       20.0                       330.0
# 4                       35.0                       380.0
#
#    Aged 65 or older Men_people  Aged 65 or older Women_people
# 0                   19144628.0                     24098571.0
# 1                       3060.0                         4060.0
# 2                      16485.0                        19550.0
# 3                       1880.0                         2460.0
# 4                       1375.0                         1745.0
#
# [5 rows x 26 columns]

# %%
#filter total amount and total people
df_2015a = df_2015.filter(["Total_amount", "Total_people"])
df_2015a
# Out:
#       Total_amount  Total_people
# 0       73642029.0    59963425.0
# 1          13422.0       11455.0
# 2          63848.0       50340.0
# 3           7664.0        7050.0
# 4           6226.0        5630.0
# ...            ...           ...
# 3237       11773.0       10755.0
# 3238         959.0         845.0
# 3239       11025.0       10125.0
# 3240      402455.0      627230.0
# 3241        2318.0        1874.0
#
# [3241 rows x 2 columns]

# %%
#Average payout per person
df_2015b= df_2015a["Total_amount"] / df_2015a["Total_people"] * 1000
df_2015b
# Out:
# 0       1228.115789
# 1       1171.715408
# 2       1268.335320
# 3       1087.092199
# 4       1105.861456
#            ...
# 3237    1094.653649
# 3238    1134.911243
# 3239    1088.888889
# 3240     641.638633
# 3241    1236.926361
# Length: 3241, dtype: float64

# %%
pay_per_person_2015 = df_2015b.iloc[[0]]
pay_per_person_2015
# Out:
# 0    1228.115789
# dtype: float64

# %%
#Average payout by state
df_2015c = df_2015.groupby(["State or area"]).mean()["Total_amount"]
df_2015c.head()
# Out:
# State or area
# Alabama            19499.253731
# Alaska              3723.620690
# American Samoa      4338.000000
# Arizona           105129.200000
# Arkansas           10360.893333
# Name: Total_amount, dtype: float64

# %%
#filter total amount and total people 2010
df_2010a = df_2010.filter(["Total_amount", "Total_people"])
df_2010a
# Out:
#       Total_amount  Total_people
# 0       58048295.0    54031968.0
# 1          10224.0       10050.0
# 2          46097.0       42065.0
# 3           6213.0        6670.0
# 4           4960.0        5180.0
# ...            ...           ...
# 3239        5925.0        8965.0
# 3240        9171.0        9745.0
# 3241         674.0         700.0
# 3242        8448.0        8940.0
# 3243      320754.0      548315.0
#
# [3243 rows x 2 columns]

# %%
#Average payout per person 2010. Look into 2010 data
df_2010b= df_2010a["Total_amount"] / df_2010a["Total_people"] * 1000
df_2010b
# Out:
# 0       1074.332421
# 1       1017.313433
# 2       1095.851658
# 3        931.484258
# 4        957.528958
#            ...
# 3239     660.903514
# 3240     941.097999
# 3241     962.857143
# 3242     944.966443
# 3243     584.981261
# Length: 3243, dtype: float64

# %%
pay_per_person_2010 = df_2010b.iloc[[0]]
pay_per_person_2010
# Out:
# 0    1074.332421
# dtype: float64

# %%
#Average payout by state 2010
df_2010c = df_2010.groupby(["State or area"]).mean()["Total_amount"]
df_2010c.head()
# Out:
# State or area
# Alabama           15460.089552
# Alaska             2755.413793
# American Samoa     3656.000000
# Arizona           79061.800000
# Arkansas           8426.920000
# Name: Total_amount, dtype: float64

# %%
#filter total amount and total people 2020
df_2020a = df_2020.filter(["Total_amount", "Total_people"])
df_2020a
# Out:
#       Total_amount  Total_people
# 0       58048295.0    64850867.0
# 1          10224.0       12300.0
# 2          46097.0       60305.0
# 3           6213.0        7160.0
# 4           4960.0        5440.0
# ...            ...           ...
# 3247           NaN       83647.0
# 3248           NaN        3190.0
# 3249           NaN        1540.0
# 3251           NaN        3310.0
# 3252           NaN         996.0
#
# [3251 rows x 2 columns]

# %%
#Average payout per person 2020. Look into 2020 data
df_2020b= df_2020a["Total_amount"] / df_2020a["Total_people"] * 1000
df_2020b
# Out:
# 0       895.104378
# 1       831.219512
# 2       764.397645
# 3       867.737430
# 4       911.764706
#            ...
# 3247           NaN
# 3248           NaN
# 3249           NaN
# 3251           NaN
# 3252           NaN
# Length: 3251, dtype: float64

# %%
pay_per_person_2020 = df_2020b.iloc[[0]]
pay_per_person_2020
# Out:
# 0    895.104378
# dtype: float64

# %%
df_2020c = df_2020.groupby(["State or area"]).mean()["Total_amount"]
df_2020c.head()
# Out:
# State or area
# Alabama           15460.089552
# Alaska             2755.413793
# American Samoa     3656.000000
# Arizona           79061.800000
# Arkansas           8426.920000
# Name: Total_amount, dtype: float64

# %%
Average_payout_per_person_df = pd.DataFrame({"2010 Avg Pay": pay_per_person_2010,
                              "2015 Avg Pay": pay_per_person_2015,
                              "2020 Avg Pay": pay_per_person_2020,
                              })
Average_payout_per_person_df
# Out:
#    2010 Avg Pay  2015 Avg Pay  2020 Avg Pay
# 0   1074.332421   1228.115789    895.104378

# %%
x_axis = [pay_per_person_2010[0], pay_per_person_2015[0], pay_per_person_2020[0]]
y_axis = ["2010 Avg Pay", "2015 Avg Pay", "2020 Avg Pay"]

plt.title("Average Payout Per Person")
plt.ylabel("Payout Amount (Dollars)")
plt.xlabel("Year")

plt.bar(y_axis, x_axis, color='b', alpha=0.25, align="center")

plt.savefig("Fig1.png")

# %%
total_2015_payout_by_state.sort_values()
# Out:
# State or area
# Northern Mariana Islands        1742.0
# Unknown                         2318.0
# American Samoa                  4338.0
# Guam                           13555.0
# U.S. Virgin Islands            23757.0
# District of Columbia           92474.0
# Alaska                        107985.0
# Wyoming                       130787.0
# North Dakota                  148607.0
# Vermont                       175424.0
# South Dakota                  198741.0
# Montana                       257378.0
# Delaware                      263586.0
# Rhode Island                  272008.0
# Hawaii                        320859.0
# New Hampshire                 374386.0
# Maine                         378016.0
# Idaho                         380771.0
# Foreign countries             402455.0
# Nebraska                      407989.0
# Utah                          468330.0
# New Mexico                    469320.0
# West Virginia                 554559.0
# Nevada                        613347.0
# Kansas                        669242.0
# Puerto Rico                   700651.0
# Mississippi                   730845.0
# Iowa                          775037.0
# Arkansas                      777067.0
# Oklahoma                      899401.0
# Connecticut                   901648.0
# Louisiana                     970664.0
# Colorado                     1012553.0
# Oregon                       1025637.0
# Kentucky                     1104954.0
# Minnesota                    1255535.0
# Alabama                      1306450.0
# South Carolina               1319981.0
# Wisconsin                    1492249.0
# Massachusetts                1550370.0
# Maryland                     1568848.0
# Arizona                      1576938.0
# Washington                   1630544.0
# Indiana                      1662629.0
# Tennessee                    1676297.0
# Missouri                     1849420.0
# Georgia                      2072628.0
# Virginia                     2111397.0
# New Jersey                   2176807.0
# North Carolina               2448991.0
# Illinois                     2758251.0
# Ohio                         2776915.0
# Michigan                     2787255.0
# Pennsylvania                 3498488.0
# New York                     4498410.0
# Texas                        4661490.0
# Florida                      5382977.0
# California                   6902804.0
# United States               73642029.0
# Name: Total_amount, dtype: float64

# %%
df_2015d = df_2015.filter(["State or area", "County", "Total_amount", "Total_people"])
df_2015d
# Out:
#             State or area      County  Total_amount  Total_people
# 0           United States         NaN    73642029.0    59963425.0
# 1                 Alabama     Autauga       13422.0       11455.0
# 2                 Alabama     Baldwin       63848.0       50340.0
# 3                 Alabama     Barbour        7664.0        7050.0
# 4                 Alabama        Bibb        6226.0        5630.0
# ...                   ...         ...           ...           ...
# 3237  U.S. Virgin Islands   St. Croix       11773.0       10755.0
# 3238  U.S. Virgin Islands    St. John         959.0         845.0
# 3239  U.S. Virgin Islands  St. Thomas       11025.0       10125.0
# 3240    Foreign countries         NaN      402455.0      627230.0
# 3241              Unknown         NaN        2318.0        1874.0
#
# [3241 rows x 4 columns]

# %%
df_2015_cali = df_2015d.loc[df_2015['State or area'] == "California"]
df_2015_cali
# Out:
#     State or area           County  Total_amount  Total_people
# 187    California          Alameda      267847.0      209210.0
# 188    California           Alpine         253.0         230.0
# 189    California           Amador       14022.0       10965.0
# 190    California            Butte       59601.0       51035.0
# 191    California        Calaveras       16864.0       13170.0
# 192    California           Colusa        4079.0        3635.0
# 193    California     Contra Costa      243335.0      177455.0
# 194    California        Del Norte        6721.0        6220.0
# 195    California        El Dorado       52752.0       40595.0
# 196    California           Fresno      147324.0      132645.0
# 197    California            Glenn        6390.0        5770.0
# 198    California         Humboldt       32411.0       28060.0
# 199    California         Imperial       27252.0       30815.0
# 200    California             Inyo        5312.0        4465.0
# 201    California             Kern      129937.0      116820.0
# 202    California            Kings       18377.0       17510.0
# 203    California             Lake       21181.0       18315.0
# 204    California           Lassen        5488.0        5175.0
# 205    California      Los Angeles     1527198.0     1300105.0
# 206    California           Madera       28217.0       24685.0
# 207    California            Marin       74443.0       50525.0
# 208    California         Mariposa        6024.0        5000.0
# 209    California        Mendocino       24391.0       21025.0
# 210    California           Merced       39043.0       36425.0
# 211    California            Modoc        2819.0        2595.0
# 212    California             Mono        1829.0        1505.0
# 213    California         Monterey       72149.0       60650.0
# 214    California             Napa       34127.0       26585.0
# 215    California           Nevada       35076.0       27255.0
# 216    California           Orange      570521.0      433330.0
# 217    California           Placer      101049.0       75325.0
# 218    California           Plumas        6977.0        5885.0
# 219    California        Riverside      433335.0      355815.0
# 220    California       Sacramento      282499.0      234660.0
# 221    California       San Benito       10338.0        8435.0
# 222    California   San Bernardino      323305.0      283675.0
# 223    California        San Diego      582196.0      475805.0
# 224    California    San Francisco      145135.0      120825.0
# 225    California      San Joaquin      125392.0      107155.0
# 226    California  San Luis Obispo       72517.0       57130.0
# 227    California        San Mateo      155372.0      111605.0
# 228    California    Santa Barbara       89146.0       71110.0
# 229    California      Santa Clara      308966.0      229055.0
# 230    California       Santa Cruz       55485.0       44385.0
# 231    California           Shasta       56562.0       48495.0
# 232    California           Sierra        1065.0         895.0
# 233    California         Siskiyou       14617.0       13260.0
# 234    California           Solano       90905.0       74015.0
# 235    California           Sonoma      126688.0       96460.0
# 236    California       Stanislaus       99776.0       85825.0
# 237    California           Sutter       18814.0       17085.0
# 238    California           Tehama       17559.0       15405.0
# 239    California          Trinity        4329.0        3870.0
# 240    California           Tulare       65949.0       63130.0
# 241    California         Tuolumne       19655.0       15835.0
# 242    California          Ventura      172562.0      134090.0
# 243    California             Yolo       33860.0       27785.0
# 244    California             Yuba       13768.0       12810.0

# %%
df_2015_cali_sort = df_2015_cali.sort_values(by=['Total_amount'])
df_2015_cali_sort
# Out:
#     State or area           County  Total_amount  Total_people
# 188    California           Alpine         253.0         230.0
# 232    California           Sierra        1065.0         895.0
# 212    California             Mono        1829.0        1505.0
# 211    California            Modoc        2819.0        2595.0
# 192    California           Colusa        4079.0        3635.0
# 239    California          Trinity        4329.0        3870.0
# 200    California             Inyo        5312.0        4465.0
# 204    California           Lassen        5488.0        5175.0
# 208    California         Mariposa        6024.0        5000.0
# 197    California            Glenn        6390.0        5770.0
# 194    California        Del Norte        6721.0        6220.0
# 218    California           Plumas        6977.0        5885.0
# 221    California       San Benito       10338.0        8435.0
# 244    California             Yuba       13768.0       12810.0
# 189    California           Amador       14022.0       10965.0
# 233    California         Siskiyou       14617.0       13260.0
# 191    California        Calaveras       16864.0       13170.0
# 238    California           Tehama       17559.0       15405.0
# 202    California            Kings       18377.0       17510.0
# 237    California           Sutter       18814.0       17085.0
# 241    California         Tuolumne       19655.0       15835.0
# 203    California             Lake       21181.0       18315.0
# 209    California        Mendocino       24391.0       21025.0
# 199    California         Imperial       27252.0       30815.0
# 206    California           Madera       28217.0       24685.0
# 198    California         Humboldt       32411.0       28060.0
# 243    California             Yolo       33860.0       27785.0
# 214    California             Napa       34127.0       26585.0
# 215    California           Nevada       35076.0       27255.0
# 210    California           Merced       39043.0       36425.0
# 195    California        El Dorado       52752.0       40595.0
# 230    California       Santa Cruz       55485.0       44385.0
# 231    California           Shasta       56562.0       48495.0
# 190    California            Butte       59601.0       51035.0
# 240    California           Tulare       65949.0       63130.0
# 213    California         Monterey       72149.0       60650.0
# 226    California  San Luis Obispo       72517.0       57130.0
# 207    California            Marin       74443.0       50525.0
# 228    California    Santa Barbara       89146.0       71110.0
# 234    California           Solano       90905.0       74015.0
# 236    California       Stanislaus       99776.0       85825.0
# 217    California           Placer      101049.0       75325.0
# 225    California      San Joaquin      125392.0      107155.0
# 235    California           Sonoma      126688.0       96460.0
# 201    California             Kern      129937.0      116820.0
# 224    California    San Francisco      145135.0      120825.0
# 196    California           Fresno      147324.0      132645.0
# 227    California        San Mateo      155372.0      111605.0
# 242    California          Ventura      172562.0      134090.0
# 193    California     Contra Costa      243335.0      177455.0
# 187    California          Alameda      267847.0      209210.0
# 220    California       Sacramento      282499.0      234660.0
# 229    California      Santa Clara      308966.0      229055.0
# 222    California   San Bernardino      323305.0      283675.0
# 219    California        Riverside      433335.0      355815.0
# 216    California           Orange      570521.0      433330.0
# 223    California        San Diego      582196.0      475805.0
# 205    California      Los Angeles     1527198.0     1300105.0

# %%
x_axis = np.arange(len(df_2015_cali_sort))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(20,4))
plt.bar(x_axis, df_2015_cali_sort["Total_amount"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, df_2015_cali_sort["County"], rotation="vertical")
plt.title("California 2015 SS Payout by County ")
plt.ylabel("Payout Amount (Dollars)")
plt.xlabel("County")


plt.show()
plt.savefig("Fig2.png")

# %%
# Create a scatter plot which compares Cali pop. to annual payout
df_2015_cali_sort.plot(kind="scatter", x="Total_people", y="Total_amount", grid=True, figsize=(8,8),
              title="Population Vs. SS Payout")


plt.show()

plt.savefig("Fig3.png")

# %% [markdown]
# # Breakdown of payout by Category

# %%
aob_2015['State or area'].unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Outlying areas',
#        'American Samoa', 'Guam', 'Northern Mariana Islands',
#        'Puerto Rico', 'U.S. Virgin Islands', 'Foreign countries',
#        'Unknown'], dtype=object)

# %%
aob_2015.columns
# Out:
# Index(['State or area', 'County', 'ANSI Code', 'Total',
#        'Retirement Retired workers', 'Retirement Spouses',
#        'Retirement Children', 'Survivors Widow(er)s and parents',
#        'Survivors Children', 'Disability Disabled workers',
#        'Disability Spouses', 'Disability Children', 'Aged 65 or older Men',
#        'Aged 65 or older Women'],
#       dtype='object')

# %%
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}

aob_2015 = aob_2015.astype(convert_dict)
aob_2015 = aob_2015[aob_2015['State or area'].str.contains('Outlying areas')==False]
aob_2015 = aob_2015[aob_2015['State or area'].str.contains('Unknown')==False]

# %%
#Calculate sums and totals for each column, grouped by state
state_totals = aob_2015.groupby('State or area').sum()['Total']
retirement_workers = aob_2015.groupby('State or area').sum()['Retirement Retired workers']
retirement_spouses = aob_2015.groupby('State or area').sum()['Retirement Spouses']
retirement_children = aob_2015.groupby('State or area').sum()['Retirement Children']
survivors_widows = aob_2015.groupby('State or area').sum()['Survivors Widow(er)s and parents']
survivors_children = aob_2015.groupby('State or area').sum()['Survivors Children']
disability_workers = aob_2015.groupby('State or area').sum()['Disability Disabled workers']
disability_spouses = aob_2015.groupby('State or area').sum()['Disability Spouses']
disability_children = aob_2015.groupby('State or area').sum()['Disability Children']
sixty_plus_men = aob_2015.groupby('State or area').sum()['Aged 65 or older Men']
sixty_plus_women = aob_2015.groupby('State or area').sum()['Aged 65 or older Women']

# %%
#Create new dataframe
summary_data = {'Total Amount': state_totals,
                'Retired Workers': retirement_workers,
               'Retirement Spouses': retirement_spouses,
               'Retirement Children': retirement_children,
               'Survivors Widow(er)s and Parents': survivors_widows,
               'Survivors Children':survivors_children,
               'Disability Workers':disability_workers,
               'Disability Spouses': disability_spouses,
               'Disability Children': disability_children,
               'Aged 65 or older Men':sixty_plus_men,
               'Aged 65 or older Women': sixty_plus_women}

summary_df = pd.DataFrame(summary_data)

# %%
#Iterate through indices to get totals into empty lists

retirement_totals = []
survivors_totals = []
disability_totals = []
sixty_five_plus_totals = []

for i, row in summary_df.iterrows():
    retirement_total=summary_df['Retired Workers'] + summary_df['Retirement Spouses'] + summary_df['Retirement Children']
    retirement_totals.append(retirement_total)
    
    survivor_total = summary_df['Survivors Widow(er)s and Parents'] + summary_df['Survivors Children']
    survivors_totals.append(survivor_total)
    
    disability_total = summary_df['Disability Workers'] + summary_df['Disability Children'] + summary_df['Disability Spouses']
    disability_totals.append(disability_total)
    
    sixty_five_plus_total = summary_df['Aged 65 or older Men'] + summary_df['Aged 65 or older Women']
    sixty_five_plus_totals.append(sixty_five_plus_total)

# %%
#Add columns to dataframe
summary_df['Retirement Totals'] = retirement_totals[1]
summary_df['Survivor Totals'] = survivors_totals[1]
summary_df['Disability Totals'] = disability_totals[1]
summary_df['Aged 65 and older Totals'] = sixty_five_plus_totals[1]
summary_df.head()
# Out:
#                 Total Amount  Retired Workers  Retirement Spouses  \
# State or area
# Alabama            1306450.0         857239.0             23559.0
# Alaska              107985.0          79378.0              1987.0
# American Samoa        4338.0           1999.0                79.0
# Arizona            1576938.0        1207691.0             32895.0
# Arkansas            777067.0         521325.0             12035.0
#
#                 Retirement Children  Survivors Widow(er)s and Parents  \
# State or area
# Alabama                      8005.0                           97166.0
# Alaska                       1068.0                            6392.0
# American Samoa                108.0                             447.0
# Arizona                      8431.0                           99151.0
# Arkansas                     4376.0                           54022.0
#
#                 Survivors Children  Disability Workers  Disability Spouses  \
# State or area
# Alabama                    33848.0            268480.0              1154.0
# Alaska                      3755.0             14509.0                54.0
# American Samoa               400.0              1162.0                11.0
# Arizona                    29020.0            188488.0               791.0
# Arkansas                   19187.0            155535.0               596.0
#
#                 Disability Children  Aged 65 or older Men  \
# State or area
# Alabama                     16988.0              458653.0
# Alaska                        837.0               46754.0
# American Samoa                132.0                1186.0
# Arizona                     10472.0              655054.0
# Arkansas                     9984.0              279199.0
#
#                 Aged 65 or older Women  Retirement Totals  Survivor Totals  \
# State or area
# Alabama                       457281.0           888803.0         131014.0
# Alaska                         34946.0            82433.0          10147.0
# American Samoa                  1034.0             2186.0            847.0
# Arizona                       604510.0          1249017.0         128171.0
# Arkansas                      274501.0           537736.0          73209.0
#
#                 Disability Totals  Aged 65 and older Totals
# State or area
# Alabama                  286622.0                  915934.0
# Alaska                    15400.0                   81700.0
# American Samoa             1305.0                    2220.0
# Arizona                  199751.0                 1259564.0
# Arkansas                 166115.0                  553700.0

# %%
summary_df.index
# Out:
# Index(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Foreign countries', 'Georgia',
#        'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota',
#        'Northern Mariana Islands', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'U.S. Virgin Islands',
#        'United States', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State or area')

# %%
#Percentage of retirement, survivor, disability, 65 plus out of total
percent_retirement = summary_df['Retirement Totals']/summary_df['Total Amount'] * 100
percent_survivor = summary_df['Survivor Totals']/summary_df['Total Amount'] * 100
percent_disability = summary_df['Disability Totals']/summary_df['Total Amount'] * 100
percent_age = summary_df['Aged 65 and older Totals']/summary_df['Total Amount'] * 100

# %%
#Create new dataframe for percentages
percent_data = {'Retirement Percentage': percent_retirement,
               'Survivor Percentage':percent_survivor,
               'Disability Percentage': percent_disability,
               '65+ Percentage': percent_age}

percentage_table_2015 = pd.DataFrame(percent_data)
percentage_table_2015.head()
# Out:
#                 Retirement Percentage  Survivor Percentage  \
# State or area
# Alabama                     68.031919            10.028244
# Alaska                      76.337454             9.396675
# American Samoa              50.391886            19.525127
# Arizona                     79.205207             8.127840
# Arkansas                    69.200725             9.421195
#
#                 Disability Percentage  65+ Percentage
# State or area
# Alabama                     21.938995       70.108615
# Alaska                      14.261240       75.658656
# American Samoa              30.082988       51.175657
# Arizona                     12.667017       79.874034
# Arkansas                    21.377179       71.255117

# %%
plt.scatter(percentage_table_2015.index.values,percentage_table_2015['Retirement Percentage'])
plt.plot(percentage_table_2015.index.values,percentage_table_2015['Retirement Percentage'])
plt.xticks(fontsize = 8, rotation = 90)
plt.show()

# %%
plt.scatter(percentage_table_2015.index.values,percentage_table_2015['Survivor Percentage'])
plt.plot(percentage_table_2015.index.values,percentage_table_2015['Survivor Percentage'])
plt.xticks(fontsize = 8,rotation = 90)
plt.show()

# %%
plt.scatter(percentage_table_2015.index.values,percentage_table_2015['Disability Percentage'])
plt.plot(percentage_table_2015.index.values,percentage_table_2015['Disability Percentage'])
plt.xticks(fontsize = 8,rotation = 90)
plt.show()

# %%
aob_2020.head()
# Out:
#    State or area   County  ANSI Code       Total  Retirement Retired workers  \
# 0  United States      NaN        NaN  58048295.0                  40662492.0
# 1        Alabama  Autauga     1001.0     10224.0                      6352.0
# 2        Alabama  Baldwin     1003.0     46097.0                     32376.0
# 3        Alabama  Barbour     1005.0      6213.0                      3636.0
# 4        Alabama     Bibb     1007.0      4960.0                      2608.0
#
#    Retirement Spouses  Retirement Children  Survivors Widow(er)s and parents  \
# 0           1343640.0             334405.0                         4884520.0
# 1               226.0                 57.0                             849.0
# 2              1097.0                251.0                            3694.0
# 3               107.0                 31.0                             499.0
# 4                97.0                 31.0                             459.0
#
#    Survivors Children  Disability Disabled workers  Disability Spouses  \
# 0           1437963.0                    8759959.0             45925.0
# 1               322.0                       2221.0                12.0
# 2              1005.0                       7164.0                39.0
# 3               186.0                       1633.0                 8.0
# 4               202.0                       1442.0                 8.0
#
#    Disability Children  Aged 65 or older Men  Aged 65 or older Women
# 0             579391.0            21573964.0              21319204.0
# 1                186.0                3437.0                  3279.0
# 2                470.0               17834.0                 15508.0
# 3                115.0                1986.0                  1858.0
# 4                114.0                1475.0                  1401.0

# %%
convert_dict = {"Total": float,
                "Retirement Retired workers": float,
               "Retirement Spouses": float,
              "Retirement Children": float,
               "Survivors Widow(er)s and parents": float,
               "Survivors Children": float,
               "Disability Disabled workers": float,
               "Disability Spouses": float,
               "Disability Children": float,
               "Aged 65 or older Men": float,
               "Aged 65 or older Women" : float}

aob_2020 = aob_2020.astype(convert_dict)
aob_2020 = aob_2020[aob_2020['State or area'].str.contains('Outlying areas')==False]

# %%
state_totals = aob_2020.groupby('State or area').sum()['Total']
retirement_workers = aob_2020.groupby('State or area').sum()['Retirement Retired workers']
retirement_spouses = aob_2020.groupby('State or area').sum()['Retirement Spouses']
retirement_children = aob_2020.groupby('State or area').sum()['Retirement Children']
survivors_widows = aob_2020.groupby('State or area').sum()['Survivors Widow(er)s and parents']
survivors_children = aob_2020.groupby('State or area').sum()['Survivors Children']
disability_workers = aob_2020.groupby('State or area').sum()['Disability Disabled workers']
disability_spouses = aob_2020.groupby('State or area').sum()['Disability Spouses']
disability_children = aob_2020.groupby('State or area').sum()['Disability Children']
sixty_plus_men = aob_2020.groupby('State or area').sum()['Aged 65 or older Men']
sixty_plus_women = aob_2020.groupby('State or area').sum()['Aged 65 or older Women']

# %%
summary_data = {'Total Amount': state_totals,
                'Retired Workers': retirement_workers,
               'Retirement Spouses': retirement_spouses,
               'Retirement Children': retirement_children,
               'Survivors Widow(er)s and Parents': survivors_widows,
               'Survivors Children':survivors_children,
               'Disability Workers':disability_workers,
               'Disability Spouses': disability_spouses,
               'Disability Children': disability_children,
               'Aged 65 or older Men':sixty_plus_men,
               'Aged 65 or older Women': sixty_plus_women}

summary_df = pd.DataFrame(summary_data)

# %%
summary_df.index
# Out:
# Index(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Foreign countries', 'Georgia',
#        'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota',
#        'Northern Mariana\n   Islands', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'U.S. Virgin Islands',
#        'United States', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State or area')

# %%
#Rename index causing inconsistency
summary_df = summary_df.rename(index = {'Northern Mariana\n   Islands': 'Northern Mariana Islands'})

# %%
retirement_totals = []
survivors_totals = []
disability_totals = []
sixty_five_plus_totals = []

for i, row in summary_df.iterrows():
    retirement_total=summary_df['Retired Workers'] + summary_df['Retirement Spouses'] + summary_df['Retirement Children']
    retirement_totals.append(retirement_total)
    
    survivor_total = summary_df['Survivors Widow(er)s and Parents'] + summary_df['Survivors Children']
    survivors_totals.append(survivor_total)
    
    disability_total = summary_df['Disability Workers'] + summary_df['Disability Children'] + summary_df['Disability Spouses']
    disability_totals.append(disability_total)
    
    sixty_five_plus_total = summary_df['Aged 65 or older Men'] + summary_df['Aged 65 or older Women']
    sixty_five_plus_totals.append(sixty_five_plus_total)

# %%
summary_df['Retirement Totals'] = retirement_totals[1]
summary_df['Survivor Totals'] = survivors_totals[1]
summary_df['Disability Totals'] = disability_totals[1]
summary_df['Aged 65 and older Totals'] = sixty_five_plus_totals[1]
summary_df.head()
# Out:
#                 Total Amount  Retired Workers  Retirement Spouses  \
# State or area
# Alabama            1035826.0         641814.0             22142.0
# Alaska               79907.0          55196.0              1459.0
# American Samoa        3656.0           1481.0                61.0
# Arizona            1185927.0         869976.0             26170.0
# Arkansas            632019.0         401438.0             11849.0
#
#                 Retirement Children  Survivors Widow(er)s and Parents  \
# State or area
# Alabama                      6222.0                           91694.0
# Alaska                        794.0                            5405.0
# American Samoa                125.0                             377.0
# Arizona                      5998.0                           87285.0
# Arkansas                     3390.0                           51740.0
#
#                 Survivors Children  Disability Workers  Disability Spouses  \
# State or area
# Alabama                    30557.0            226415.0              1200.0
# Alaska                      3340.0             12809.0                53.0
# American Samoa               406.0              1056.0                12.0
# Arizona                    25651.0            160072.0               760.0
# Arkansas                   17217.0            136145.0               679.0
#
#                 Disability Children  Aged 65 or older Men  \
# State or area
# Alabama                     15773.0              340178.0
# Alaska                        835.0               31659.0
# American Samoa                138.0                 905.0
# Arizona                     10008.0              465347.0
# Arkansas                     9560.0              214426.0
#
#                 Aged 65 or older Women  Retirement Totals  Survivor Totals  \
# State or area
# Alabama                       344826.0           670178.0         122251.0
# Alaska                         24091.0            57449.0           8745.0
# American Samoa                   751.0             1667.0            783.0
# Arizona                       425736.0           902144.0         112936.0
# Arkansas                      211710.0           416677.0          68957.0
#
#                 Disability Totals  Aged 65 and older Totals
# State or area
# Alabama                  243388.0                  685004.0
# Alaska                    13697.0                   55750.0
# American Samoa             1206.0                    1656.0
# Arizona                  170840.0                  891083.0
# Arkansas                 146384.0                  426136.0

# %%
#Percentage of retirement, survivor, disability, 65 plus out of total

percent_retirement = summary_df['Retirement Totals']/summary_df['Total Amount'] * 100
percent_survivor = summary_df['Survivor Totals']/summary_df['Total Amount'] * 100
percent_disability = summary_df['Disability Totals']/summary_df['Total Amount'] * 100
percent_age = summary_df['Aged 65 and older Totals']/summary_df['Total Amount'] * 100

# %%
percent_data = {'Retirement Percentage': percent_retirement,
               'Survivor Percentage':percent_survivor,
               'Disability Percentage': percent_disability,
               '65+ Percentage': percent_age}

percentage_table_2020 = pd.DataFrame(percent_data)
percentage_table_2020.head()
# Out:
#                 Retirement Percentage  Survivor Percentage  \
# State or area
# Alabama                     64.699863            11.802272
# Alaska                      71.894828            10.943972
# American Samoa              45.596280            21.416849
# Arizona                     76.070787             9.523014
# Arkansas                    65.927923            10.910590
#
#                 Disability Percentage  65+ Percentage
# State or area
# Alabama                     23.496997       66.131184
# Alaska                      17.141177       69.768606
# American Samoa              32.986871       45.295405
# Arizona                     14.405608       75.138099
# Arkansas                    23.161329       67.424555

# %%
plt.scatter(percentage_table_2020.index.values,percentage_table_2020['Retirement Percentage'], color = 'r', label = '2020')
plt.plot(percentage_table_2020.index.values,percentage_table_2020['Retirement Percentage'], color = 'r')
plt.xticks(fontsize = 8, rotation = 90)

plt.scatter(percentage_table_2015.index.values,percentage_table_2015['Retirement Percentage'], color = 'b', label = '2015')
plt.plot(percentage_table_2015.index.values,percentage_table_2015['Retirement Percentage'], color = 'b')
plt.xticks(fontsize = 8, rotation = 90)
plt.legend(loc = 'best')
plt.title('Retirement Percentage by State')
plt.ylabel('Percent of Total')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('retirement_prct.png', dpi=100)

# %%
plt.scatter(percentage_table_2020.index.values,percentage_table_2020['Survivor Percentage'])
plt.plot(percentage_table_2020.index.values,percentage_table_2020['Survivor Percentage'])
plt.xticks(fontsize = 8,rotation = 90)
plt.show()

# %%
plt.scatter(percentage_table_2020.index.values,percentage_table_2020['Disability Percentage'])
plt.plot(percentage_table_2020.index.values,percentage_table_2020['Disability Percentage'])
plt.xticks(fontsize = 8,rotation = 90)
plt.show()

# %%
plt.scatter(percentage_table_2020.index.values,percentage_table_2020['Survivor Percentage'], color = 'r', label = '2020')
plt.plot(percentage_table_2020.index.values,percentage_table_2020['Survivor Percentage'], color = 'r')
plt.xticks(fontsize = 8,rotation = 90)

plt.scatter(percentage_table_2015.index.values,percentage_table_2015['Survivor Percentage'],color = 'b', label = '2015')
plt.plot(percentage_table_2015.index.values,percentage_table_2015['Survivor Percentage'], color = 'b')
plt.xticks(fontsize = 8,rotation = 90)
plt.legend(loc = 'best')
plt.title('Survivor Percentage by State')
plt.ylabel('Percent of Total')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('survivor_prct.png', dpi=100)

# %%
men_2015 = aob_2015.groupby('State or area').sum()['Aged 65 or older Men']
women_2015 = aob_2015.groupby('State or area').sum()['Aged 65 or older Women']

# %%
men_2020 = aob_2020.groupby('State or area').sum()['Aged 65 or older Men']
women_2020 = aob_2020.groupby('State or area').sum()['Aged 65 or older Women']

# %%
gender_data = {'65+ Men 2015': men_2015,
              '65+ Women 2015': women_2015,
              '65+ Men 2020': men_2020,
              '65+ Women 2020': women_2020}

payout_by_gender = pd.DataFrame(gender_data)

# %%
payout_sorted_2015 = payout_by_gender.sort_values('65+ Men 2015', ascending = False)
top_5 = payout_sorted_2015.head(6)
top_5_2015 = top_5.drop(top_5.index[0])
top_5_2015
# Out:
#               65+ Men 2015  65+ Women 2015  65+ Men 2020  65+ Women 2020
# California       2820965.0       2702064.0     2077325.0       2004942.0
# Florida          2200783.0       2106019.0     1621902.0       1549344.0
# Texas            1879927.0       1716715.0     1342911.0       1246589.0
# New York         1708855.0       1835797.0     1332836.0       1450536.0
# Pennsylvania     1359240.0       1385327.0     1060986.0       1107996.0

# %%
payout_sorted_2020 = payout_by_gender.sort_values('65+ Men 2020', ascending = False)
top_5 = payout_sorted_2020.head(6)
top_5_2020 = top_5.drop(top_5.index[0])
top_5_2020
# Out:
#               65+ Men 2015  65+ Women 2015  65+ Men 2020  65+ Women 2020
# California       2820965.0       2702064.0     2077325.0       2004942.0
# Florida          2200783.0       2106019.0     1621902.0       1549344.0
# Texas            1879927.0       1716715.0     1342911.0       1246589.0
# New York         1708855.0       1835797.0     1332836.0       1450536.0
# Pennsylvania     1359240.0       1385327.0     1060986.0       1107996.0

# %%
top_5_2020.plot(y=["65+ Men 2015", "65+ Women 2015"], kind="bar")

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('gender_payout_2020.png', dpi=100)

# %%
top_5_2015.plot(y=["65+ Men 2020", "65+ Women 2020"], kind="bar")
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('gender_payout_2015.png', dpi=100)
